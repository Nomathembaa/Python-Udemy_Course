# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
from plotly import __version__

# %%
print(__version__)
# Out:
# 5.9.0

# %%
import cufflinks as cf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23920\189640202.py in <module>
# ----> 1 import cufflinks as cf
#
# ModuleNotFoundError: No module named 'cufflinks'

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23920\2446349587.py in <module>
# ----> 1 cf.go_offline()
#
# NameError: name 'cf' is not defined

# %%
dataset = pd.read_csv(myfile)
dataset[columns].iplot(kind='box')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23920\1702818547.py in <module>
# ----> 1 dataset = pd.read_csv(myfile)
#       2 dataset[columns].iplot(kind='box')
#
# NameError: name 'myfile' is not defined

# %%
# DATA
df = pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())

# %%
df.head()
# Out:
#           A         B         C         D
# 0  0.653082 -0.406547 -0.264634 -1.506022
# 1  1.156447  1.337499 -0.762984 -0.222924
# 2 -1.187383  0.894931 -0.545979 -0.222774
# 3 -0.098975  0.070186 -2.150634 -2.635812
# 4  0.628130 -0.746546  0.421056  0.604161

# %%
df2 = pd.DataFrame({'Category':['A','B','C'],'vaues':[32,43,50]})

# %% [markdown]
# df2

# %%
df2
# Out:
#   Category  vaues
# 0        A     32
# 1        B     43
# 2        C     50

# %%
df
# Out:
#            A         B         C         D
# 0   0.653082 -0.406547 -0.264634 -1.506022
# 1   1.156447  1.337499 -0.762984 -0.222924
# 2  -1.187383  0.894931 -0.545979 -0.222774
# 3  -0.098975  0.070186 -2.150634 -2.635812
# 4   0.628130 -0.746546  0.421056  0.604161
# ..       ...       ...       ...       ...
# 95  0.239004 -0.129925 -0.106796  0.314187
# 96 -0.568554  0.244882  0.817096  0.013548
# 97 -0.533889  0.948709 -1.306804  0.587449
# 98  0.898721 -0.866875 -0.239400 -0.836871
# 99 -0.309256 -1.734920  0.501639 -0.938338
#
# [100 rows x 4 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='scatter',x='A',y='B')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df2.plot(kind='bar',x='Category')
# Out:
# <AxesSubplot:xlabel='Category'>

# %%
df
# Out:
#            A         B         C         D
# 0   0.653082 -0.406547 -0.264634 -1.506022
# 1   1.156447  1.337499 -0.762984 -0.222924
# 2  -1.187383  0.894931 -0.545979 -0.222774
# 3  -0.098975  0.070186 -2.150634 -2.635812
# 4   0.628130 -0.746546  0.421056  0.604161
# ..       ...       ...       ...       ...
# 95  0.239004 -0.129925 -0.106796  0.314187
# 96 -0.568554  0.244882  0.817096  0.013548
# 97 -0.533889  0.948709 -1.306804  0.587449
# 98  0.898721 -0.866875 -0.239400 -0.836871
# 99 -0.309256 -1.734920  0.501639 -0.938338
#
# [100 rows x 4 columns]

# %%
df.count().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='box',color='purple')
# Out:
# <AxesSubplot:>

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[500,400,300,200,100]})

# %%
df3.iplot(kind='surface')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23920\556259678.py in <module>
# ----> 1 df3.iplot(kind='surface')
#
# C:\Python\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'iplot'
